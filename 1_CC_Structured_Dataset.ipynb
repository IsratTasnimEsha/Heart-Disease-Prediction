# %%
import pandas as pd
import os
import csv
os.chdir('Resources/')

# %%
df1 = pd.read_csv('0_Raw_Data_1.csv')
df1.head()
# Out:
#    Age Sex ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   40   M           ATA                   140        289.0
# 1   49   F           NAP                   160        180.0
# 2   37   M           ATA                   130        283.0
# 3   48   F           ASY                   138        214.0
# 4   54   M           NAP                   150        195.0
#
#    FastingBloodSugar RestingECG  MaximumHeartRate ExerciseAngina  Oldpeak  \
# 0                  0     Normal               172              N      0.0
# 1                  0     Normal               156              N      1.0
# 2                  0         ST                98              N      0.0
# 3                  0     Normal               108              Y      1.5
# 4                  0     Normal               122              N      0.0
#
#   ST_Slope  HeartDisease
# 0       Up             0
# 1     Flat             1
# 2       Up             0
# 3     Flat             1
# 4       Up             0

# %%
df1['Sex'] = df1['Sex'].replace({'F': 'Female', 'M': 'Male'})
df1['ChestPainType'] = df1['ChestPainType'].replace({'TA': 'Typical Angina', 'ATA': 'Atypical Angina', 'NAP': 'Non-anginal Pain', 'ASY': 'Asymptomatic'})
df1['FastingBloodSugar'] = df1['FastingBloodSugar'].replace({0: 'No', 1: 'Yes'})
df1['RestingECG'] = df1['RestingECG'].replace({'ST': 'Abnormal ST-T Wave', 'LVH': 'LV Hypertrophy'})
df1['ExerciseAngina'] = df1['ExerciseAngina'].replace({'N': 'No', 'Y': 'Yes'})
df1['ST_Slope'] = df1['ST_Slope'].replace({'Up': 'Upsloping', 'Down': 'Downsloping'})
df1['HeartDisease'] = df1['HeartDisease'].replace({0: 'No', 1: 'Yes'})
df1.head()
# Out:
#    Age     Sex     ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   40    Male   Atypical Angina                   140        289.0
# 1   49  Female  Non-anginal Pain                   160        180.0
# 2   37    Male   Atypical Angina                   130        283.0
# 3   48  Female      Asymptomatic                   138        214.0
# 4   54    Male  Non-anginal Pain                   150        195.0
#
#   FastingBloodSugar          RestingECG  MaximumHeartRate ExerciseAngina  \
# 0                No              Normal               172             No
# 1                No              Normal               156             No
# 2                No  Abnormal ST-T Wave                98             No
# 3                No              Normal               108            Yes
# 4                No              Normal               122             No
#
#    Oldpeak   ST_Slope HeartDisease
# 0      0.0  Upsloping           No
# 1      1.0       Flat          Yes
# ...

# %%
df2 = pd.read_csv('0_Raw_Data_2.csv')
df2.head()
# Out:
#    Age  Sex  ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   63    1              3                   145          233
# 1   37    1              2                   130          250
# 2   41    0              1                   130          204
# 3   56    1              1                   120          236
# 4   57    0              0                   120          354
#
#    FastingBloodSugar  RestingECG  MaximumHeartRate  ExerciseAngina  Oldpeak  \
# 0                  1           0               150               0      2.3
# 1                  0           1               187               0      3.5
# 2                  0           0               172               0      1.4
# 3                  0           1               178               0      0.8
# 4                  0           1               163               1      0.6
#
#    ST_Slope  NumMajorVessels  Thalassemia  HeartDisease
# 0         0                0            1             1
# ...

# %%
df2['Sex'] = df2['Sex'].replace({0: 'Female', 1: 'Male'})
df2['ChestPainType'] = df2['ChestPainType'].replace({0: 'Typical Angina', 1: 'Atypical Angina', 2: 'Non-anginal Pain', 3: 'Asymptomatic'})
df2['FastingBloodSugar'] = df2['FastingBloodSugar'].replace({0: 'No', 1: 'Yes'})
df2['RestingECG'] = df2['RestingECG'].replace({0: 'Normal', 1: 'Abnormal ST-T Wave', 2: 'LV Hypertrophy'})
df2['ExerciseAngina'] = df2['ExerciseAngina'].replace({0: 'No', 1: 'Yes'})
df2['ST_Slope'] = df2['ST_Slope'].replace({0: 'Upsloping', 1: 'Flat', 2: 'Downsloping'})
df2['HeartDisease'] = df2['HeartDisease'].replace({0: 'No', 1: 'Yes'})
df2.head()
# Out:
#    Age     Sex     ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   63    Male      Asymptomatic                   145          233
# 1   37    Male  Non-anginal Pain                   130          250
# 2   41  Female   Atypical Angina                   130          204
# 3   56    Male   Atypical Angina                   120          236
# 4   57  Female    Typical Angina                   120          354
#
#   FastingBloodSugar          RestingECG  MaximumHeartRate ExerciseAngina  \
# 0               Yes              Normal               150             No
# 1                No  Abnormal ST-T Wave               187             No
# 2                No              Normal               172             No
# 3                No  Abnormal ST-T Wave               178             No
# 4                No  Abnormal ST-T Wave               163            Yes
#
#    Oldpeak     ST_Slope  NumMajorVessels  Thalassemia HeartDisease
# ...

# %%
df2 = df2.drop(['NumMajorVessels', 'Thalassemia'], axis='columns')
df2.head()
# Out:
#    Age     Sex     ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   63    Male      Asymptomatic                   145          233
# 1   37    Male  Non-anginal Pain                   130          250
# 2   41  Female   Atypical Angina                   130          204
# 3   56    Male   Atypical Angina                   120          236
# 4   57  Female    Typical Angina                   120          354
#
#   FastingBloodSugar          RestingECG  MaximumHeartRate ExerciseAngina  \
# 0               Yes              Normal               150             No
# 1                No  Abnormal ST-T Wave               187             No
# 2                No              Normal               172             No
# 3                No  Abnormal ST-T Wave               178             No
# 4                No  Abnormal ST-T Wave               163            Yes
#
#    Oldpeak     ST_Slope HeartDisease
# 0      2.3    Upsloping          Yes
# 1      3.5    Upsloping          Yes
# ...

# %%
df3 = pd.read_csv('0_Raw_Data_3.csv')
df3.head()
# Out:
#    Age  Sex  ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   53    1              2                   171          NaN
# 1   40    1              0                    94        229.0
# 2   49    1              2                   133        142.0
# 3   43    1              0                   138        295.0
# 4   31    1              1                   199          NaN
#
#    FastingBloodSugar  RestingECG  MaximumHeartRate  ExerciseAngina  Oldpeak  \
# 0                  0           1               147               0      5.3
# 1                  0           1               115               0      3.7
# 2                  0           0               202               1      5.0
# 3                  1           1               153               0      3.2
# 4                  0           2               136               0      5.3
#
#    ST_Slope  NumMajorVessels  HeartDisease
# 0       3.0                3             1
# 1       1.0                1             0
# ...

# %%
df3['Sex'] = df3['Sex'].replace({0: 'Female', 1: 'Male'})
df3['ChestPainType'] = df3['ChestPainType'].replace({0: 'Typical Angina', 1: 'Atypical Angina', 2: 'Non-anginal Pain', 3: 'Asymptomatic'})
df3['FastingBloodSugar'] = df3['FastingBloodSugar'].replace({0: 'No', 1: 'Yes'})
df3['RestingECG'] = df3['RestingECG'].replace({0: 'Normal', 1: 'Abnormal ST-T Wave', 2: 'LV Hypertrophy'})
df3['ExerciseAngina'] = df3['ExerciseAngina'].replace({0: 'No', 1: 'Yes'})
df3['ST_Slope'] = df3['ST_Slope'].replace({1: 'Upsloping', 2: 'Flat', 3: 'Downsloping'})
df3['HeartDisease'] = df3['HeartDisease'].replace({0: 'No', 1: 'Yes'})
df3.head()
# Out:
#    Age   Sex     ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   53  Male  Non-anginal Pain                   171          NaN
# 1   40  Male    Typical Angina                    94        229.0
# 2   49  Male  Non-anginal Pain                   133        142.0
# 3   43  Male    Typical Angina                   138        295.0
# 4   31  Male   Atypical Angina                   199          NaN
#
#   FastingBloodSugar          RestingECG  MaximumHeartRate ExerciseAngina  \
# 0                No  Abnormal ST-T Wave               147             No
# 1                No  Abnormal ST-T Wave               115             No
# 2                No              Normal               202            Yes
# 3               Yes  Abnormal ST-T Wave               153             No
# 4                No      LV Hypertrophy               136             No
#
#    Oldpeak     ST_Slope  NumMajorVessels HeartDisease
# 0      5.3  Downsloping                3          Yes
# ...

# %%
df3 = df3.drop(['NumMajorVessels'], axis='columns')
df3.head()
# Out:
#    Age   Sex     ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   53  Male  Non-anginal Pain                   171          NaN
# 1   40  Male    Typical Angina                    94        229.0
# 2   49  Male  Non-anginal Pain                   133        142.0
# 3   43  Male    Typical Angina                   138        295.0
# 4   31  Male   Atypical Angina                   199          NaN
#
#   FastingBloodSugar          RestingECG  MaximumHeartRate ExerciseAngina  \
# 0                No  Abnormal ST-T Wave               147             No
# 1                No  Abnormal ST-T Wave               115             No
# 2                No              Normal               202            Yes
# 3               Yes  Abnormal ST-T Wave               153             No
# 4                No      LV Hypertrophy               136             No
#
#    Oldpeak     ST_Slope HeartDisease
# 0      5.3  Downsloping          Yes
# 1      3.7    Upsloping           No
# ...

# %%
df4 = pd.read_csv('0_Raw_Data_4.csv')
df4.head()
# Out:
#    Age  Sex  ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   60    1              3                   145          233
# 1   35    1              2                   130          250
# 2   41    0              1                   130          204
# 3   55    1              1                   120          236
# 4   56    0              0                   120          354
#
#    FastingBloodSugar  RestingECG  MaximumHeartRate  ExerciseAngina  Oldpeak  \
# 0                  1           0               150               0      2.3
# 1                  0           1               187               0      3.5
# 2                  0           0               172               0      1.4
# 3                  0           1               178               0      0.8
# 4                  0           1               163               1      0.6
#
#    ST_Slope  NumMajorVessels  Thalassemia  HeartDisease
# 0         0                0            1             1
# ...

# %%
df4['Sex'] = df4['Sex'].replace({0: 'Female', 1: 'Male'})
df4['ChestPainType'] = df4['ChestPainType'].replace({0: 'Typical Angina', 1: 'Atypical Angina', 2: 'Non-anginal Pain', 3: 'Asymptomatic'})
df4['FastingBloodSugar'] = df4['FastingBloodSugar'].replace({0: 'No', 1: 'Yes'})
df4['RestingECG'] = df4['RestingECG'].replace({0: 'Normal', 1: 'Abnormal ST-T Wave', 2: 'LV Hypertrophy'})
df4['ExerciseAngina'] = df4['ExerciseAngina'].replace({0: 'No', 1: 'Yes'})
df4['ST_Slope'] = df4['ST_Slope'].replace({0: 'Upsloping', 1: 'Flat', 2: 'Downsloping'})
df4['HeartDisease'] = df4['HeartDisease'].replace({0: 'No', 1: 'Yes'})
df4.head()
# Out:
#    Age     Sex     ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   60    Male      Asymptomatic                   145          233
# 1   35    Male  Non-anginal Pain                   130          250
# 2   41  Female   Atypical Angina                   130          204
# 3   55    Male   Atypical Angina                   120          236
# 4   56  Female    Typical Angina                   120          354
#
#   FastingBloodSugar          RestingECG  MaximumHeartRate ExerciseAngina  \
# 0               Yes              Normal               150             No
# 1                No  Abnormal ST-T Wave               187             No
# 2                No              Normal               172             No
# 3                No  Abnormal ST-T Wave               178             No
# 4                No  Abnormal ST-T Wave               163            Yes
#
#    Oldpeak     ST_Slope  NumMajorVessels  Thalassemia HeartDisease
# ...

# %%
df4 = df4.drop(['NumMajorVessels', 'Thalassemia'], axis='columns')
df4.head()
# Out:
#    Age     Sex     ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   60    Male      Asymptomatic                   145          233
# 1   35    Male  Non-anginal Pain                   130          250
# 2   41  Female   Atypical Angina                   130          204
# 3   55    Male   Atypical Angina                   120          236
# 4   56  Female    Typical Angina                   120          354
#
#   FastingBloodSugar          RestingECG  MaximumHeartRate ExerciseAngina  \
# 0               Yes              Normal               150             No
# 1                No  Abnormal ST-T Wave               187             No
# 2                No              Normal               172             No
# 3                No  Abnormal ST-T Wave               178             No
# 4                No  Abnormal ST-T Wave               163            Yes
#
#    Oldpeak     ST_Slope HeartDisease
# 0      2.3    Upsloping          Yes
# 1      3.5    Upsloping          Yes
# ...

# %%
df5 = pd.read_csv('0_Raw_Data_5.csv')
df5.head()
# Out:
#    Age  Sex  ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   70    1              4                   130          322
# 1   67    0              3                   115          564
# 2   57    1              2                   124          261
# 3   64    1              4                   128          263
# 4   74    0              2                   120          269
#
#    FastingBloodSugar  RestingECG  MaximumHeartRate  ExerciseAngina  Oldpeak  \
# 0                  0           2               109               0      2.4
# 1                  0           2               160               0      1.6
# 2                  0           0               141               0      0.3
# 3                  0           0               105               1      0.2
# 4                  0           2               121               1      0.2
#
#    ST_Slope  NumMajorVessels  Thalassemia HeartDisease
# 0         2                3            3     Presence
# ...

# %%
df5['Sex'] = df5['Sex'].replace({0: 'Female', 1: 'Male'})
df5['ChestPainType'] = df5['ChestPainType'].replace({1: 'Typical Angina', 2: 'Atypical Angina', 3: 'Non-anginal Pain', 4: 'Asymptomatic'})
df5['FastingBloodSugar'] = df5['FastingBloodSugar'].replace({0: 'No', 1: 'Yes'})
df5['RestingECG'] = df5['RestingECG'].replace({0: 'Normal', 1: 'Abnormal ST-T Wave', 2: 'LV Hypertrophy'})
df5['ExerciseAngina'] = df5['ExerciseAngina'].replace({0: 'No', 1: 'Yes'})
df5['ST_Slope'] = df5['ST_Slope'].replace({1: 'Upsloping', 2: 'Flat', 3: 'Downsloping'})
df5['HeartDisease'] = df5['HeartDisease'].replace({'Absence': 'No', 'Presence': 'Yes'})
df5.head()
# Out:
#    Age     Sex     ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   70    Male      Asymptomatic                   130          322
# 1   67  Female  Non-anginal Pain                   115          564
# 2   57    Male   Atypical Angina                   124          261
# 3   64    Male      Asymptomatic                   128          263
# 4   74  Female   Atypical Angina                   120          269
#
#   FastingBloodSugar      RestingECG  MaximumHeartRate ExerciseAngina  Oldpeak  \
# 0                No  LV Hypertrophy               109             No      2.4
# 1                No  LV Hypertrophy               160             No      1.6
# 2                No          Normal               141             No      0.3
# 3                No          Normal               105            Yes      0.2
# 4                No  LV Hypertrophy               121            Yes      0.2
#
#     ST_Slope  NumMajorVessels  Thalassemia HeartDisease
# ...

# %%
df5 = df5.drop(['NumMajorVessels', 'Thalassemia'], axis='columns')
df5.head()
# Out:
#    Age     Sex     ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   70    Male      Asymptomatic                   130          322
# 1   67  Female  Non-anginal Pain                   115          564
# 2   57    Male   Atypical Angina                   124          261
# 3   64    Male      Asymptomatic                   128          263
# 4   74  Female   Atypical Angina                   120          269
#
#   FastingBloodSugar      RestingECG  MaximumHeartRate ExerciseAngina  Oldpeak  \
# 0                No  LV Hypertrophy               109             No      2.4
# 1                No  LV Hypertrophy               160             No      1.6
# 2                No          Normal               141             No      0.3
# 3                No          Normal               105            Yes      0.2
# 4                No  LV Hypertrophy               121            Yes      0.2
#
#     ST_Slope HeartDisease
# 0       Flat          Yes
# 1       Flat           No
# ...

# %%
df6 = pd.read_csv('0_Raw_Data_6.csv')
df6.head()
# Out:
#    ID  Age     Sex    Dataset    ChestPainType  RestingBloodPressure  \
# 0   1   63    Male  Cleveland   typical angina                 145.0
# 1   2   67    Male  Cleveland     asymptomatic                 160.0
# 2   3   67    Male  Cleveland     asymptomatic                 120.0
# 3   4   37    Male  Cleveland      non-anginal                 130.0
# 4   5   41  Female  Cleveland  atypical angina                 130.0
#
#    Cholesterol FastingBloodSugar      RestingECG  MaximumHeartRate  \
# 0        233.0              True  lv hypertrophy             150.0
# 1        286.0             False  lv hypertrophy             108.0
# 2        229.0             False  lv hypertrophy             129.0
# 3        250.0             False          normal             187.0
# 4        204.0             False  lv hypertrophy             172.0
#
#   ExerciseAngina  Oldpeak     ST_Slope  NumMajorVessels        Thalassemia  \
# ...

# %%
df6['ChestPainType'] = df6['ChestPainType'].replace({'typical angina': 'Typical Angina', 'atypical angina': 'Atypical Angina', 'non-anginal': 'Non-anginal Pain', 'asymptomatic': 'Asymptomatic'})
df6['FastingBloodSugar'] = df6['FastingBloodSugar'].replace({False: 'No', True: 'Yes'})
df6['RestingECG'] = df6['RestingECG'].replace({0: 'Normal', 'normal': 'Normal', 'st-t abnormality': 'Abnormal ST-T Wave', 'lv hypertrophy': 'LV Hypertrophy'})
df6['ExerciseAngina'] = df6['ExerciseAngina'].replace({False: 'No', True: 'Yes'})
df6['ST_Slope'] = df6['ST_Slope'].replace({'upsloping': 'Upsloping', 'flat': 'Flat', 'downsloping': 'Downsloping'})
df6['HeartDisease'] = df6['HeartDisease'].replace({0: 'No', 1: 'Yes', 2: 'Yes', 3: 'Yes', 4: 'Yes'})
df6.head()
# Out:
#    ID  Age     Sex    Dataset     ChestPainType  RestingBloodPressure  \
# 0   1   63    Male  Cleveland    Typical Angina                 145.0
# 1   2   67    Male  Cleveland      Asymptomatic                 160.0
# 2   3   67    Male  Cleveland      Asymptomatic                 120.0
# 3   4   37    Male  Cleveland  Non-anginal Pain                 130.0
# 4   5   41  Female  Cleveland   Atypical Angina                 130.0
#
#    Cholesterol FastingBloodSugar      RestingECG  MaximumHeartRate  \
# 0        233.0               Yes  LV Hypertrophy             150.0
# 1        286.0                No  LV Hypertrophy             108.0
# 2        229.0                No  LV Hypertrophy             129.0
# 3        250.0                No          Normal             187.0
# 4        204.0                No  LV Hypertrophy             172.0
#
#   ExerciseAngina  Oldpeak     ST_Slope  NumMajorVessels        Thalassemia  \
# ...

# %%
df6 = df6.drop(['ID', 'Dataset', 'NumMajorVessels', 'Thalassemia'], axis='columns')
df6.head()
# Out:
#    Age     Sex     ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   63    Male    Typical Angina                 145.0        233.0
# 1   67    Male      Asymptomatic                 160.0        286.0
# 2   67    Male      Asymptomatic                 120.0        229.0
# 3   37    Male  Non-anginal Pain                 130.0        250.0
# 4   41  Female   Atypical Angina                 130.0        204.0
#
#   FastingBloodSugar      RestingECG  MaximumHeartRate ExerciseAngina  Oldpeak  \
# 0               Yes  LV Hypertrophy             150.0             No      2.3
# 1                No  LV Hypertrophy             108.0            Yes      1.5
# 2                No  LV Hypertrophy             129.0            Yes      2.6
# 3                No          Normal             187.0             No      3.5
# 4                No  LV Hypertrophy             172.0             No      1.4
#
#       ST_Slope HeartDisease
# 0  Downsloping           No
# 1         Flat          Yes
# ...

# %%
df7 = pd.read_csv('0_Raw_Data_7.csv')
df7.head()
# Out:
#    Age  Sex  ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   52    1              0                   125          212
# 1   53    1              0                   140          203
# 2   70    1              0                   145          174
# 3   61    1              0                   148          203
# 4   62    0              0                   138          294
#
#    FastingBloodSugar  RestingECG  MaximumHeartRate  ExerciseAngina  Oldpeak  \
# 0                  0           1               168               0      1.0
# 1                  1           0               155               1      3.1
# 2                  0           1               125               1      2.6
# 3                  0           1               161               0      0.0
# 4                  1           1               106               0      1.9
#
#    ST_Slope  NumMajorVessels  Thalassemia  HeartDisease
# 0         2                2            3             0
# ...

# %%
df7['Sex'] = df7['Sex'].replace({0: 'Female', 1: 'Male'})
df7['ChestPainType'] = df7['ChestPainType'].replace({0: 'Typical Angina', 1: 'Atypical Angina', 2: 'Non-anginal Pain', 3: 'Asymptomatic'})
df7['FastingBloodSugar'] = df7['FastingBloodSugar'].replace({0: 'No', 1: 'Yes'})
df7['RestingECG'] = df7['RestingECG'].replace({0: 'Normal', 1: 'Abnormal ST-T Wave', 2: 'LV Hypertrophy'})
df7['ExerciseAngina'] = df7['ExerciseAngina'].replace({0: 'No', 1: 'Yes'})
df7['ST_Slope'] = df7['ST_Slope'].replace({0: 'Upsloping', 1: 'Flat', 2: 'Downsloping'})
df7['HeartDisease'] = df7['HeartDisease'].replace({0: 'No', 1: 'Yes'})
df7.head()
# Out:
#    Age     Sex   ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   52    Male  Typical Angina                   125          212
# 1   53    Male  Typical Angina                   140          203
# 2   70    Male  Typical Angina                   145          174
# 3   61    Male  Typical Angina                   148          203
# 4   62  Female  Typical Angina                   138          294
#
#   FastingBloodSugar          RestingECG  MaximumHeartRate ExerciseAngina  \
# 0                No  Abnormal ST-T Wave               168             No
# 1               Yes              Normal               155            Yes
# 2                No  Abnormal ST-T Wave               125            Yes
# 3                No  Abnormal ST-T Wave               161             No
# 4               Yes  Abnormal ST-T Wave               106             No
#
#    Oldpeak     ST_Slope  NumMajorVessels  Thalassemia HeartDisease
# ...

# %%
df7 = df7.drop(['NumMajorVessels', 'Thalassemia'], axis='columns')
df7.head()
# Out:
#    Age     Sex   ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   52    Male  Typical Angina                   125          212
# 1   53    Male  Typical Angina                   140          203
# 2   70    Male  Typical Angina                   145          174
# 3   61    Male  Typical Angina                   148          203
# 4   62  Female  Typical Angina                   138          294
#
#   FastingBloodSugar          RestingECG  MaximumHeartRate ExerciseAngina  \
# 0                No  Abnormal ST-T Wave               168             No
# 1               Yes              Normal               155            Yes
# 2                No  Abnormal ST-T Wave               125            Yes
# 3                No  Abnormal ST-T Wave               161             No
# 4               Yes  Abnormal ST-T Wave               106             No
#
#    Oldpeak     ST_Slope HeartDisease
# 0      1.0  Downsloping           No
# 1      3.1    Upsloping           No
# ...

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7], axis='rows')
df
# Out:
#      Age     Sex     ChestPainType  RestingBloodPressure  Cholesterol  \
# 0     40    Male   Atypical Angina                 140.0        289.0
# 1     49  Female  Non-anginal Pain                 160.0        180.0
# 2     37    Male   Atypical Angina                 130.0        283.0
# 3     48  Female      Asymptomatic                 138.0        214.0
# 4     54    Male  Non-anginal Pain                 150.0        195.0
# ..   ...     ...               ...                   ...          ...
# 297   68  Female  Non-anginal Pain                 120.0        211.0
# 298   44  Female  Non-anginal Pain                 108.0        141.0
# 299   52    Male    Typical Angina                 128.0        255.0
# 300   59    Male      Asymptomatic                 160.0        273.0
# 301   54    Male    Typical Angina                 120.0        188.0
#
#     FastingBloodSugar          RestingECG  MaximumHeartRate ExerciseAngina  \
# ...

# %%
# df = df.dropna()

# %%
df.to_csv('1_CC_Structured_Data.csv', index=False)
