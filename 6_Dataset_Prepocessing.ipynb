# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA
from sklearn.ensemble import IsolationForest
import joblib
import os
os.chdir('Resources/')

# %%
df = pd.read_csv('4_Encrypted_Data.csv')
df.head()
# Out:
#                                                  Age  \
# 0                                                  0
# 1  5086600012490731442943930571085139155474036451295
# 2  5207383839504054707363518626041174678109639052454
# 3  7627115353597159256912609008269949662070481573805
# 4  1753169937090950706840792726073953718547374599...
#
#                                                  Sex  \
# 0                                                  0
# 1  7071071391752259975941988339317745999154049513885
# 2                                                  0
# 3  7071071391752259975941988339317745999154049513885
# 4                                                  0
#
#                                        ChestPainType  \
# 0                                                  0
# 1  3693394287169285625561633551529311552288291726451
# 2                                                  0
# 3  1262349230074411541365961405356601051676844088...
# ...

# %%
imputer = SimpleImputer(strategy='mean')
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)
df_imputed
# Out:
#                Age           Sex  ChestPainType  RestingBloodPressure  \
# 0     0.000000e+00  0.000000e+00   0.000000e+00          0.000000e+00
# 1     5.086600e+48  7.071071e+48   3.693394e+48          5.175915e+48
# 2     5.207384e+48  0.000000e+00   0.000000e+00          1.649044e+49
# 3     7.627115e+48  7.071071e+48   1.262349e+49          2.821355e+49
# 4     1.753170e+49  0.000000e+00   3.693394e+48          3.533400e+49
# ...            ...           ...            ...                   ...
# 4039  1.343464e+50  7.071071e+48   3.693394e+48          3.072516e+49
# 4040  1.970132e+49  7.071071e+48   3.693394e+48          1.550917e+50
# 4041  4.994932e+49  0.000000e+00   1.326557e+49          7.665529e+49
# 4042  1.526813e+50  0.000000e+00   1.262349e+49          5.175915e+48
# 4043  1.753170e+49  0.000000e+00   1.326557e+49          3.072516e+49
#
#        Cholesterol  FastingBloodSugar    RestingECG  MaximumHeartRate  \
# ...

# %%
X = df_imputed.drop(['HeartDisease'], axis='columns')
X
# Out:
#                Age           Sex  ChestPainType  RestingBloodPressure  \
# 0     0.000000e+00  0.000000e+00   0.000000e+00          0.000000e+00
# 1     5.086600e+48  7.071071e+48   3.693394e+48          5.175915e+48
# 2     5.207384e+48  0.000000e+00   0.000000e+00          1.649044e+49
# 3     7.627115e+48  7.071071e+48   1.262349e+49          2.821355e+49
# 4     1.753170e+49  0.000000e+00   3.693394e+48          3.533400e+49
# ...            ...           ...            ...                   ...
# 4039  1.343464e+50  7.071071e+48   3.693394e+48          3.072516e+49
# 4040  1.970132e+49  7.071071e+48   3.693394e+48          1.550917e+50
# 4041  4.994932e+49  0.000000e+00   1.326557e+49          7.665529e+49
# 4042  1.526813e+50  0.000000e+00   1.262349e+49          5.175915e+48
# 4043  1.753170e+49  0.000000e+00   1.326557e+49          3.072516e+49
#
#        Cholesterol  FastingBloodSugar    RestingECG  MaximumHeartRate  \
# ...

# %%
Y = df[['HeartDisease']]
Y
# Out:
#       HeartDisease
# 0                0
# 1                1
# 2                0
# 3                1
# 4                0
# ...            ...
# 4039             1
# 4040             1
# 4041             0
# 4042             0
# 4043             0
#
# [4044 rows x 1 columns]

# %%
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
df_scaled
# Out:
#            Age       Sex  ChestPainType  RestingBloodPressure  Cholesterol  \
# 0    -0.992464 -0.574685      -1.459175             -0.716525    -0.882519
# 1    -0.946321  1.740083      -0.788087             -0.684805    -0.877571
# 2    -0.945225 -0.574685      -1.459175             -0.615464    -0.859719
# 3    -0.923275  1.740083       0.834507             -0.543620    -0.845338
# 4    -0.833425 -0.574685      -0.788087             -0.499982    -0.850792
# ...        ...       ...            ...                   ...          ...
# 4039  0.226260  1.740083      -0.788087             -0.528227    -0.787925
# 4040 -0.813743  1.740083      -0.788087              0.233946     1.454180
# 4041 -0.539349 -0.574685       0.951172             -0.246747     0.177855
# 4042  0.392585 -0.574685       0.834507             -0.684805    -0.821597
# 4043 -0.833425 -0.574685       0.951172             -0.528227    -0.739541
#
# ...

# %%
df_scaled = pd.concat([df_scaled, Y], axis=1)
df_scaled.to_csv('6_Preprocessed_Data.csv', index=False)

# %%
joblib.dump(scaler, '6_Scaler.joblib')
# Out:
# ['6_Scaler.joblib']
