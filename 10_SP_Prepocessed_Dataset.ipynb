# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA
from sklearn.ensemble import IsolationForest
import joblib
import os
os.chdir('Resources/')

from custom_tuple_scaler import CustomTupleScaler

# %%
df = pd.read_csv('9_SP_Imputed_Data.csv')
df.head()
# Out:
#                                                  Age  \
# 0  (116117118567918454538443635441930044584366525...
# 1  (116117118567918454538443635441930044584366525...
# 2  (116117118567918454538443635441930044584366525...
# 3  (116117118567918454538443635441930044584366525...
# 4  (116117118567918454538443635441930044584366525...
#
#                                                  Sex  \
# 0  (115216133156897905997902213226564416198983593...
# 1  (115216133156897905997902213226564416198983593...
# 2  (115216133156897905997902213226564416198983593...
# 3  (115216133156897905997902213226564416198983593...
# 4  (115216133156897905997902213226564416198983593...
#
#                                        ChestPainType  \
# 0  (534062771043874878230123617229893967373724032...
# 1  (534062771043874878230123617229893967373724032...
# 2  (534062771043874878230123617229893967373724032...
# 3  (534062771043874878230123617229893967373724032...
# ...

# %%
X = df.drop(['HeartDisease'], axis='columns')
X
# Out:
#                                                     Age  \
# 0     (116117118567918454538443635441930044584366525...
# 1     (116117118567918454538443635441930044584366525...
# 2     (116117118567918454538443635441930044584366525...
# 3     (116117118567918454538443635441930044584366525...
# 4     (116117118567918454538443635441930044584366525...
# ...                                                 ...
# 4039  (116117118567918454538443635441930044584366525...
# 4040  (116117118567918454538443635441930044584366525...
# 4041  (116117118567918454538443635441930044584366525...
# 4042  (116117118567918454538443635441930044584366525...
# 4043  (116117118567918454538443635441930044584366525...
#
#                                                     Sex  \
# 0     (115216133156897905997902213226564416198983593...
# 1     (115216133156897905997902213226564416198983593...
# 2     (115216133156897905997902213226564416198983593...
# 3     (115216133156897905997902213226564416198983593...
# ...

# %%
Y = df[['HeartDisease']]
Y
# Out:
#       HeartDisease
# 0                0
# 1                1
# 2                0
# 3                1
# 4                0
# ...            ...
# 4039             1
# 4040             1
# 4041             0
# 4042             0
# 4043             0
#
# [4044 rows x 1 columns]

# %%
custom_scaler = CustomTupleScaler()
df_scaled = custom_scaler.fit_transform(X)

df_scaled = pd.DataFrame(df_scaled, columns=X.columns)

print(df_scaled)
# Out:
# g:\Thesis - Copy\Resources\custom_tuple_scaler.py:17: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   c2_values = X.applymap(self._extract_c2)
# g:\Thesis - Copy\Resources\custom_tuple_scaler.py:22: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   c2_values = X.applymap(self._extract_c2)
#            Age       Sex  ChestPainType  RestingBloodPressure  Cholesterol  \
# 0    -0.676784 -0.574685      -0.958796             -0.486543     0.380882
# 1     0.151470  1.740083      -0.229040              0.260218    -1.024946
# 2     0.199419 -0.574685      -0.958796              0.888249    -0.030683
# 3     1.595826  1.740083       1.448842              0.626765     0.356164
# 4    -0.156582 -0.574685      -0.229040              1.635011    -1.245251
# ...        ...       ...            ...                   ...          ...
# 4039  0.363621  1.740083      -0.229040             -1.233305     0.150382
# ...

# %%
df_scaled = pd.concat([df_scaled, Y], axis=1)
df_scaled.to_csv('10_SP_Preprocessed_Data.csv', index=False)

# %%
joblib.dump(custom_scaler, '10_SP_Scaler.joblib')
# Out:
# ['10_SP_Scaler.joblib']
