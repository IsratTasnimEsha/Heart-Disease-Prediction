# %%
import os
import csv
import pandas as pd
import numpy as np
from phe import paillier
import pickle
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from math import ceil
import subprocess

# %%
file_names = [
    'Attribute_Age.py', 'Attribute_Sex.py', 'Attribute_ChestPainType.py',
    'Attribute_RestingBloodPressure.py', 'Attribute_Cholesterol.py', 'Attribute_FastingBloodSugar.py',
    'Attribute_RestingECG.py', 'Attribute_MaximumHeartRate.py', 'Attribute_ExerciseAngina.py',
    'Attribute_Oldpeak.py', 'Attribute_ST_Slope.py', 'Attribute_HeartDisease.py'
]

for file_name in file_names:
    subprocess.run(['python', file_name])

# %%
df1 = pd.read_csv('Encrypted_Age.csv')
df2 = pd.read_csv('Encrypted_Sex.csv')
df3 = pd.read_csv('Encrypted_ChestPainType.csv')
df4 = pd.read_csv('Encrypted_RestingBloodPressure.csv')
df5 = pd.read_csv('Encrypted_Cholesterol.csv')
df6 = pd.read_csv('Encrypted_FastingBloodSugar.csv')
df7 = pd.read_csv('Encrypted_RestingECG.csv')
df8 = pd.read_csv('Encrypted_MaximumHeartRate.csv')
df9 = pd.read_csv('Encrypted_ExerciseAngina.csv')
df10 = pd.read_csv('Encrypted_Oldpeak.csv')
df11 = pd.read_csv('Encrypted_ST_Slope.csv')
df12 = pd.read_csv('Encrypted_HeartDisease.csv')

# %%
df = pd.concat([df1['Age'], df2['Sex'], df3['ChestPainType'], df4['RestingBloodPressure'],
                df5['Cholesterol'], df6['FastingBloodSugar'], df7['RestingECG'],
                df8['MaximumHeartRate'], df9['ExerciseAngina'], df10['Oldpeak'],
                df11['ST_Slope'], df12['HeartDisease']], axis=1)
df
# Out:
#                                                     Age  \
# 0     <phe.paillier.EncryptedNumber object at 0x0000...
# 1     <phe.paillier.EncryptedNumber object at 0x0000...
# 2     <phe.paillier.EncryptedNumber object at 0x0000...
# 3     <phe.paillier.EncryptedNumber object at 0x0000...
# 4     <phe.paillier.EncryptedNumber object at 0x0000...
# ...                                                 ...
# 2855  <phe.paillier.EncryptedNumber object at 0x0000...
# 2856  <phe.paillier.EncryptedNumber object at 0x0000...
# 2857  <phe.paillier.EncryptedNumber object at 0x0000...
# 2858  <phe.paillier.EncryptedNumber object at 0x0000...
# 2859  <phe.paillier.EncryptedNumber object at 0x0000...
#
#                                                     Sex  \
# 0     <phe.paillier.EncryptedNumber object at 0x0000...
# 1     <phe.paillier.EncryptedNumber object at 0x0000...
# 2     <phe.paillier.EncryptedNumber object at 0x0000...
# 3     <phe.paillier.EncryptedNumber object at 0x0000...
# ...

# %%
os.chdir('..')
df.to_csv('4_Encrypted_Dataset\Encrypted_Data.csv', index=False)
os.chdir(os.getcwd())
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\E'
# <>:2: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\USER\AppData\Local\Temp\ipykernel_28760\1500810919.py:2: SyntaxWarning: invalid escape sequence '\E'
#   df.to_csv('4_Encrypted_Dataset\Encrypted_Data.csv', index=False)
